# %%
import pandas as pd

# %%
customer_data = pd.read_csv(r"C:\Users\vishal\OneDrive\Desktop\Data Warehouse Project\archive (4)\olist_customers_dataset.csv")
geolocation_data = pd.read_csv(r"C:\Users\vishal\OneDrive\Desktop\Data Warehouse Project\archive (4)\olist_geolocation_dataset.csv")
order_item_data = pd.read_csv(r"C:\Users\vishal\OneDrive\Desktop\Data Warehouse Project\archive (4)\olist_order_items_dataset.csv")
order_payment_data = pd.read_csv(r"C:\Users\vishal\OneDrive\Desktop\Data Warehouse Project\archive (4)\olist_order_payments_dataset.csv")
order_review_data = pd.read_csv(r"C:\Users\vishal\OneDrive\Desktop\Data Warehouse Project\archive (4)\olist_order_reviews_dataset.csv")
orders_data = pd.read_csv(r"C:\Users\vishal\OneDrive\Desktop\Data Warehouse Project\archive (4)\olist_orders_dataset.csv")
product_data = pd.read_csv(r"C:\Users\vishal\OneDrive\Desktop\Data Warehouse Project\archive (4)\olist_products_dataset.csv")
sellers_data = pd.read_csv(r"C:\Users\vishal\OneDrive\Desktop\Data Warehouse Project\archive (4)\olist_sellers_dataset.csv")
category_name_dat = pd.read_csv(r"C:\Users\vishal\OneDrive\Desktop\Data Warehouse Project\archive (4)\product_category_name_translation.csv")

# %%
customer_data
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
duplicates = customer_data[customer_data.duplicated()]
# To display the duplicate rows
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_unique_id, customer_zip_code_prefix, customer_city, customer_state]
# Index: []

# %%
#Checking for null values
null_check = customer_data.isnull().sum()
print(null_check)
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
#Removing Duplicates from data set
customer_data.drop_duplicates()
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
geolocation_data
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %%
#Checking for null values
null = geolocation_data.isnull().sum()
print(null)
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
order_item_data
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
#Checkinh for duplicates
duplicates = order_item_data[order_item_data.duplicated(subset=['product_id', 'order_id'])]
print(duplicates)
# Out:
#                                 order_id  order_item_id  \
# 14      0008288aa423d2a3f00fcb17cd7d8719              2
# 33      00143d0f86d6fbd9f9b38ab440ac16f5              2
# 34      00143d0f86d6fbd9f9b38ab440ac16f5              3
# 43      001ab0a7578dd66cd4b0a71f5b6e1e41              2
# 44      001ab0a7578dd66cd4b0a71f5b6e1e41              3
# ...                                  ...            ...
# 112617  ffecd5a79a0084f6a592288c67e3c298              3
# 112635  fff8287bbae429a99bb7e8c21d151c41              2
# 112641  fffb9224b6fc7c43ebb0904318b10b5f              2
# 112642  fffb9224b6fc7c43ebb0904318b10b5f              3
# 112643  fffb9224b6fc7c43ebb0904318b10b5f              4
#
#                               product_id                         seller_id  \
# 14      368c6c730842d78016ad823897a372db  1f50f920176fa81dab994f9023523100
# 33      e95ee6822b66ac6058e2e4aff656071a  a17f621c590ea0fab3d5d883e1630ec6
# ...

# %%
order_payment_data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
# Checking for null values in 'payment_type' and 'payment_sequential' columns
null = order_payment_data.isnull().sum()
print(null)
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
#Checking for duplicates
duplicates = order_payment_data[order_payment_data.duplicated(subset=['order_id'])]
print(duplicates)
# Out:
#                                 order_id  payment_sequential payment_type  \
# 1456    683bf306149bb869980b68d48a1bd6ab                   1  credit_card
# 2324    e6a66a8350bb88497954d37688ab123e                   2      voucher
# 2393    8e5148bee82a7e42c5f9ba76161dc51a                   1  credit_card
# 2414    816ccd9d21435796e8ffa9802b2a782f                   1  credit_card
# 2497    2cbcb371aee438c59b722a21d83597e0                   2      voucher
# ...                                  ...                 ...          ...
# 103778  fd86c80924b4be8fb7f58c4ecc680dae                   1  credit_card
# 103817  6d4616de4341417e17978fe57aec1c46                   1  credit_card
# 103860  31bc09fdbd701a7a4f9b55b5955b8687                   6      voucher
# 103869  c9b01bef18eb84888f0fd071b8413b38                   1  credit_card
# 103874  d41f1036712e18ee525939d08b7a1c98                   1  credit_card
#
#         payment_installments  payment_value
# ...

# %%
order_review_data
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
# Checking for null values in 'payment_type' and 'payment_sequential' columns
null = order_review_data.isnull().sum()
print(null)
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
# Checking for duplicates in 'review_id' and 'order_id' columns
duplicates = order_review_data[order_review_data.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [review_id, order_id, review_score, review_comment_title, review_comment_message, review_creation_date, review_answer_timestamp]
# Index: []

# %%
# Drop columns 'review_comment_title' and 'review_comment_message' if they contain only null values
order_review_data = order_review_data.drop(columns=['review_comment_title', 'review_comment_message'])

# %%
order_review_data
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_creation_date review_answer_timestamp
# ...

# %%
orders_data
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
# Convert 'order_purchase_timestamp' to string type
orders_data['order_purchase_timestamp'] = orders_data['order_purchase_timestamp'].astype(str)
# Split 'order_delivered_customer_date' column into date and time
orders_data[['order_purchase_date', 'order_purchase_time']] = orders_data['order_delivered_customer_date'].str.split(" ", expand=True)


# Convert 'order_delivered_customer_date' to string type
orders_data['order_delivered_customer_date'] = orders_data['order_delivered_customer_date'].astype(str)
# Split 'order_delivered_customer_date' column into date and time
orders_data[['order_delivered_date', 'order_delivered_time']] = orders_data['order_delivered_customer_date'].str.split(" ", expand=True)


# Convert 'order_estimated_delivery_date' to string type
orders_data['order_estimated_delivery_date'] = orders_data['order_estimated_delivery_date'].astype(str)
# Split 'order_delivered_customer_date' column into date and time
orders_data[['order_estimated_delivery_date', 'order_estimated_delivery_time']] = orders_data['order_estimated_delivery_date'].str.split(" ", expand=True)

# %%
orders_data
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
# Drop columns which is not in use
orders_data = orders_data.drop(columns=['order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_time' ])

# %%
orders_data
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_estimated_delivery_date order_purchase_date  \
# ...

# %%
product_data
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
#Checking for null values
null = product_data.isnull().sum()
print(null)
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
product_data.dropna(inplace=True)

# %%
product_data
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
sellers_data
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %%
#Checking for null values
null = sellers_data.isnull().sum()
print(null)
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
#There is no need to check duplicates maybe all data were different because any seller can oreder another product from same city or state

# %%
category_name_dat
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %%
#Checking for null values
null = category_name_dat.isnull().sum()
print(null)
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
#Checking for duplicates
duplicates = category_name_dat[category_name_dat.duplicated(subset=['product_category_name', 'product_category_name_english'])]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [product_category_name, product_category_name_english]
# Index: []

# %%
#Data Loading Task

# %%
#installing library

# %%
customer_data.columns
# Out:
# Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state'],
#       dtype='object')

# %%
customer_data['customer_unique_id'].dtype
# Out:
# dtype('O')

# %%
import pyodbc

# %%
pyodbc.drivers()
# Out:
# ['SQL Server',
#  'SQL Server Native Client 11.0',
#  'SQL Server Native Client RDA 11.0',
#  'ODBC Driver 17 for SQL Server',
#  'Microsoft Access Driver (*.mdb, *.accdb)',
#  'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)',
#  'Microsoft Access Text Driver (*.txt, *.csv)']

# %%
import pyodbc

conn = pyodbc.connect(
    Trusted_Connection = "Yes",  # Corrected the parameter name
    Driver = '{ODBC Driver 17 for SQL Server}',  # Corrected the parameter format
    Server = 'LAPTOP-TOC9H3F0\\VISHALDEMODB',  # Use double backslashes to escape the backslash in the server name
    Database = 'Data Warehouse'
)

cursor = conn.cursor()

# %%
customer_data
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
customer_data.columns
# Out:
# Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state'],
#       dtype='object')

# %%
cursor.execute("""
    CREATE TABLE customer_data (
        customer_id NVARCHAR(50),
        customer_unique_id NVARCHAR(50),
        customer_zip_code_prefix INT,
        customer_city NVARCHAR(50),
        customer_state NVARCHAR(10)
    )
""")

# %%
for row in customer_data.itertuples():
    cursor.execute(''' 
    INSERT INTO [Data Warehouse].dbo.customer_data (customer_id, customer_unique_id, customer_zip_code_prefix, customer_city, customer_state)
    VALUES (?, ?, ?, ?, ?)
    ''', 
    (row.customer_id, row.customer_unique_id, row.customer_zip_code_prefix, row.customer_city, row.customer_state)
    )

conn.commit()

# %%
geolocation_data.columns
# Out:
# Index(['geolocation_zip_code_prefix', 'geolocation_lat', 'geolocation_lng',
#        'geolocation_city', 'geolocation_state'],
#       dtype='object')

# %%
geolocation_data
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %%
cursor.execute("""
    CREATE TABLE geolocation_data (
        geolocation_zip_code_prefix INT,
        geolocation_lat FLOAT,
        geolocation_lng FLOAT,
        geolocation_city NVARCHAR(50),
        geolocation_state NVARCHAR(10)
    )
""")

# %%
for row in geolocation_data.itertuples():
    cursor.execute(''' 
    INSERT INTO [Data Warehouse].dbo.geolocation_data (geolocation_zip_code_prefix, geolocation_lat, geolocation_lng, geolocation_city, geolocation_state)
    VALUES (?, ?, ?, ?, ?)
    ''', 
    row.geolocation_zip_code_prefix,
    row.geolocation_lat,
    row.geolocation_lng,
    row.geolocation_city,
    row.geolocation_state
    )
    
conn.commit()

# %%
order_item_data
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
order_item_data.columns
# Out:
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value'],
#       dtype='object')

# %%
cursor.execute("""
    CREATE TABLE order_item_data (
        order_id NVARCHAR(50),
        order_item_id int,
        product_id NVARCHAR(50),
        seller_id NVARCHAR(50),
        shipping_limit_date DATETIME,
        price float,
        freight_value float
        
    )
""")

# %%
for row in order_item_data.itertuples():
    cursor.execute(''' 
    INSERT INTO [Data Warehouse].dbo.order_item_data (order_id, order_item_id, product_id, seller_id, shipping_limit_date, price, freight_value)
    VALUES (
        ?,                           -- order_id
        ?,                           -- order_item_id
        ?,                           -- product_id
        ?,                           -- seller_id
        ?,                           -- shipping_limit_date
        ?,                           -- price
        ?                            -- freight_value
    )
    ''', 
    row.order_id,
    row.order_item_id,
    row.product_id,
    row.seller_id,
    row.shipping_limit_date,
    row.price,
    row.freight_value
    )
    
conn.commit()

# %%
order_payment_data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
order_payment_data.columns
# Out:
# Index(['order_id', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value'],
#       dtype='object')

# %%
cursor.execute("""
    CREATE TABLE order_payment_data (
        order_id VARBINARY(MAX),
        payment_sequential int,
        payment_type NVARCHAR(50),
        payment_installments INT,
        payment_value float
        
    )
""")

# %%
for row in order_payment_data.itertuples():
    cursor.execute(''' 
    INSERT INTO [Data Warehouse].dbo.order_payment_data (order_id, payment_sequential, payment_type, payment_installments, payment_value)
    VALUES (
        CONVERT(VARBINARY(MAX), ?),  -- order_id
        ?,                           -- payment_sequential
        CONVERT(NVARCHAR(MAX), ?),   -- payment_type (assuming it's NVARCHAR)
        ?,                           -- payment_installments
        ?                            -- payment_value
    )
    ''', 
    row.order_id,
    row.payment_sequential,
    row.payment_type,
    row.payment_installments,
    row.payment_value
    )
    
conn.commit()

# %%
order_review_data
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_creation_date review_answer_timestamp
# ...

# %%
order_review_data.columns
# Out:
# Index(['review_id', 'order_id', 'review_score', 'review_comment_title',
#        'review_comment_message', 'review_creation_date',
#        'review_answer_timestamp'],
#       dtype='object')

# %%
cursor.execute("""
    CREATE TABLE order_review_data (
        review_id NVARCHAR(50),
        order_id NVARCHAR(50),
        review_score int,
        review_creation_date DATETIME,
        review_answer_timestamp DATETIME
        
    )
""")

# %%
for row in order_review_data.itertuples():
    cursor.execute(''' 
    INSERT INTO [Data Warehouse].dbo.order_review_data (review_id, order_id, review_score, review_creation_date, review_answer_timestamp)
    VALUES (
        ?,                           -- review_id
        ?,                           -- order_id
        ?,                           -- review_score
        ?,                           -- review_creation_date
        ?                            -- review_answer_timestamp
    )
    ''', 
    row.review_id,
    row.order_id,
    row.review_score,
    row.review_creation_date,
    row.review_answer_timestamp
    )
    
conn.commit()

# %%
product_data
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
product_data.columns
# Out:
# Index(['product_id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm'],
#       dtype='object')

# %%
cursor.execute("""
    CREATE TABLE product_data (
        product_id NVARCHAR(50),
        product_category_name VARCHAR(50),
        product_name_lenght float,
        product_description_lenght float,
        product_photos_qty float,
        product_weight_g float,
        product_length_cm float,
        product_height_cm float,
        product_width_cm float      
    )
""")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 cursor.execute("""
#       2     CREATE TABLE product_data (
#       3         product_id NVARCHAR(50),
#       4         product_category_name VARCHAR(50),
#       5         product_name_lenght float,
#       6         product_description_lenght float,
#       7         product_photos_qty float,
#       8         product_weight_g float,
#       9         product_length_cm float,
#      10         product_height_cm float,
#      11         product_width_cm float
#      12     )
#      13 """)
#
# ProgrammingError: ('42S01', "[42S01] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]There is already an object named 'product_data' in the database. (2714) (SQLExecDirectW)")

# %%
# Close the connection
conn.close()

# %%
for row in product_data.itertuples():
    cursor.execute('''
        INSERT INTO [Data Warehouse].dbo.product_data (
            product_id,
            product_category_name,
            product_name_length,  -- Replace with the actual column name from your DataFrame
            product_description_length,  -- Replace with the actual column name from your DataFrame
            product_photos_qty,  -- Replace with the actual column name from your DataFrame
            product_weight_g,  -- Replace with the actual column name from your DataFrame
            product_length_cm,  -- Replace with the actual column name from your DataFrame
            product_height_cm,  -- Replace with the actual column name from your DataFrame
            product_width_cm  -- Replace with the actual column name from your DataFrame
        )
        VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
    ''', 
    row.product_id,
    row.product_category_name,
    row.product_name_length,  # Replace with the actual column name from your DataFrame
    row.product_description_length,  # Replace with the actual column name from your DataFrame
    row.product_photos_qty,  # Replace with the actual column name from your DataFrame
    row.product_weight_g,  # Replace with the actual column name from your DataFrame
    row.product_length_cm,  # Replace with the actual column name from your DataFrame
    row.product_height_cm,  # Replace with the actual column name from your DataFrame
    row.product_width_cm  # Replace with the actual column name from your DataFrame
    )

# Commit the transaction
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for row in product_data.itertuples():
#       2     cursor.execute('''
#       3         INSERT INTO [Data Warehouse].dbo.product_data (
#       4             product_id,
#    (...)
#      24     row.product_width_cm  # Replace with the actual column name from your DataFrame
#      25     )
#      27 # Commit the transaction
#
# NameError: name 'product_data' is not defined

# %%
sellers_data.head(10)                  #The table is delerted mistakenly but it is present in Staginf layer
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
# 5  c240c4061717ac1806ae6ee72be3533b                   20920
# 6  e49c26c3edfa46d227d5121a6b6e4d37                   55325
# 7  1b938a7ec6ac5061a66a3766e0e75f90                   16304
# 8  768a86e36ad6aae3d03ee3c6433d61df                    1529
# 9  ccc4bbb5f32a6ab2b7066a4130f114e3                   80310
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP
# 5     rio de janeiro           RJ
# 6             brejao           PE
# ...

# %%
sellers_data.columns
# Out:
# Index(['seller_id', 'seller_zip_code_prefix', 'seller_city', 'seller_state'], dtype='object')

# %%
cursor.execute("""
    CREATE TABLE sellers_data (
        seller_id NVARCHAR(50),
        seller_zip_code_prefix NVARCHAR(10),
        seller_city NVARCHAR(50),
        seller_state NVARCHAR(10)     
    )
""")

# %%
for row in sellers_data.itertuples():
    cursor.execute(''' 
    INSERT INTO [Data Warehouse].dbo.sellers_data (seller_id, seller_zip_code_prefix, seller_city, seller_state)
    VALUES (
        ?,                          
        ?,                           
        ?,                           
        ?                           
    )
    ''', 
    row.seller_id,
    row.seller_zip_code_prefix,
    row.seller_city,
    row.seller_state
    )
    
conn.commit()
